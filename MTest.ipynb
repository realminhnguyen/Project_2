# %%
import pandas as pd
import hvplot.pandas
import numpy as np
from pathlib import Path

# %%
ICE_USDCNY_1D = Path("Resources/ICE_USDCNY_1D.csv")
ICE_USDJPY_1D = Path("Resources/ICE_USDJPY_1D.csv")

# %%
usdcny_1D = pd.read_csv(
    ICE_USDCNY_1D,
    index_col="time",
    infer_datetime_format=True,
    parse_dates=True,
)
# Out:
# /var/folders/jp/x_d0tm_j75v5bcxxbpv_nllh0000gp/T/ipykernel_32284/2405115755.py:1: FutureWarning:
#
# The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.

# %%
usdcny_1D = usdcny_1D.rename_axis("Date")

# %%
usdcny_1D = usdcny_1D.sort_index()
usdcny_1D = usdcny_1D[["close"]]

usdcny_1D.head(10)
# Out:
#              close
# Date
# 1981-01-02  1.5341
# 1981-01-05  1.5418
# 1981-01-06  1.5264
# 1981-01-07  1.5264
# 1981-01-08  1.5264
# 1981-01-09  1.5371
# 1981-01-12  1.5371
# 1981-01-13  1.5449
# 1981-01-14  1.5449
# 1981-01-15  1.5449

# %%
usdcny_1D.index
# Out:
# DatetimeIndex(['1981-01-02', '1981-01-05', '1981-01-06', '1981-01-07', '1981-01-08', '1981-01-09', '1981-01-12', '1981-01-13', '1981-01-14', '1981-01-15',
#                ...
#                '2024-03-01', '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14'], dtype='datetime64[ns]', name='Date', length=10919, freq=None)

# %%
usdcny_1D.tail(10)
# Out:
#              close
# Date
# 2024-03-01  7.1955
# 2024-03-04  7.1982
# 2024-03-05  7.1960
# 2024-03-06  7.1966
# 2024-03-07  7.1921
# 2024-03-08  7.1850
# 2024-03-11  7.1815
# 2024-03-12  7.1795
# 2024-03-13  7.1856
# 2024-03-14  7.1927

# %%
usdcny_1D.plot(title = "USDCNY Exchange Rate")
# Out:
# <Axes: title={'center': 'USDCNY Exchange Rate'}, xlabel='Date'>

# %%
usdcny_1D.dtypes
# Out:
# close    float64
# dtype: object

# %%
# CNY pegged to USD. Artificial valuation.

start_date = '1997-01-01'
end_date = '2005-01-31'

# Boolean indexing to select rows within the specified date range
usdcny_pegged = usdcny_1D[(usdcny_1D.index >= start_date) & (usdcny_1D.index <= end_date)]
usdcny_pegged
# Out:
#              close
# Date
# 1997-01-02  8.3283
# 1997-01-03  8.3283
# 1997-01-06  8.3280
# 1997-01-07  8.3276
# 1997-01-08  8.3272
# ...            ...
# 2005-01-25  8.2767
# 2005-01-26  8.2760
# 2005-01-27  8.2767
# 2005-01-28  8.2767
# 2005-01-31  8.2767
#
# [1974 rows x 1 columns]

# %%
usdcny_pegged.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Unpegged in July 2005, CNY becoming a free market currency
start_date = '2005-01-31'
end_date = '2024-03-14'

# Boolean indexing to select rows within the specified date range
usdcny_unpeg = usdcny_1D[(usdcny_1D.index >= start_date) & (usdcny_1D.index <= end_date)]
usdcny_unpeg
# Out:
#              close
# Date
# 2005-01-31  8.2767
# 2005-02-01  8.2760
# 2005-02-02  8.2767
# 2005-02-03  8.2767
# 2005-02-04  8.2767
# ...            ...
# 2024-03-08  7.1850
# 2024-03-11  7.1815
# 2024-03-12  7.1795
# 2024-03-13  7.1856
# 2024-03-14  7.1927
#
# [4988 rows x 1 columns]

# %%
usdcny_unpeg.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Post-financial crisis

start_date = '2010-01-01'
end_date = '2024-03-14'

# Boolean indexing to select rows within the specified date range
usdcny_post2010 = usdcny_1D[(usdcny_1D.index >= start_date) & (usdcny_1D.index <= end_date)]
usdcny_post2010
# Out:
#              close
# Date
# 2010-01-01  6.8269
# 2010-01-04  6.8278
# 2010-01-05  6.8268
# 2010-01-06  6.8276
# 2010-01-07  6.8278
# ...            ...
# 2024-03-08  7.1850
# 2024-03-11  7.1815
# 2024-03-12  7.1795
# 2024-03-13  7.1856
# 2024-03-14  7.1927
#
# [3704 rows x 1 columns]

# %%
usdcny_post2010.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Post-currency devaluation August 2015

start_date = '2015-08-01'
end_date = '2024-03-14'

# Boolean indexing to select rows within the specified date range
usdcny_post2015 = usdcny_1D[(usdcny_1D.index >= start_date) & (usdcny_1D.index <= end_date)]
usdcny_post2015
# Out:
#              close
# Date
# 2015-08-03  6.2087
# 2015-08-04  6.2085
# 2015-08-05  6.2095
# 2015-08-06  6.2095
# 2015-08-07  6.2085
# ...            ...
# 2024-03-08  7.1850
# 2024-03-11  7.1815
# 2024-03-12  7.1795
# 2024-03-13  7.1856
# 2024-03-14  7.1927
#
# [2248 rows x 1 columns]

# %%
usdcny_post2015.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from IPython.display import display
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from time import time
import seaborn as sns
sns.set(style="whitegrid")

RANDOM_SEED = np.random.seed(0)

# %%
#plot
plt.figure(figsize=(14,4))
plt.plot(usdcny_post2015)
plt.title('USDCNY Exchange Rate Post 2015 Devaluation', fontsize=20)
plt.ylabel('Rate', fontsize=16)
# Out:
# Text(0, 0.5, 'Rate')

# %%
def check_stationarity(ts):
    dftest = adfuller(ts)
    adf = dftest[0]
    pvalue = dftest[1]
    critical_value = dftest[4]['5%']
    if (pvalue < 0.05) and (adf < critical_value):
        print('The series is stationary')
    else:
        print('The series is NOT stationary')

# %%
# STL(Seasonal-Trend) Decomposition
plt.rc('figure',figsize=(14,8))
plt.rc('font',size=15)

result = seasonal_decompose(usdcny_post2015, model='additive', period = 365)
fig = result.plot()

# %%
check_stationarity(usdcny_post2015)
# Out:
# The series is NOT stationary

# %%
# Finding p
plot_pacf(usdcny_post2015.diff().dropna());

# p value is either 3-1=2 or 4-1=3

# %%
# Finding d
check_stationarity(usdcny_post2015)
# Out:
# The series is NOT stationary

# %%
# First differentiattion
usdcny_post2015_diff = usdcny_post2015.diff()
usdcny_post2015_diff.dropna(inplace = True)

# %%
usdcny_post2015_diff.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
check_stationarity(usdcny_post2015_diff)
# d value is 1
# Out:
# The series is stationary

# %%
# Finding q
plot_acf(usdcny_post2015.diff().dropna());

# q is 3-1=2

# %%
# Need to assign a frequency to our date index so tha forecast will have associated dates
usdcny_post2015.index = pd.DatetimeIndex(usdcny_post2015.index).to_period('D')

# %%
# (p,d,q) = (2,1,2)
arima = ARIMA(usdcny_post2015,order=(2,1,2))
model_fit = arima.fit()
# Out:
# /Users/Minh/anaconda3/envs/algotrading/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
from pmdarima.arima import auto_arima

model = auto_arima(usdcny_post2015, start_p=1, start_q=1,
                      test='adf',
                      max_p=5, max_q=5,
                      m=1,             
                      d=1,          
                      seasonal=False,   
                      start_P=0, 
                      D=None, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-11689.412, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-11693.337, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-11691.411, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-11691.412, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-11693.995, Time=0.07 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.394 seconds

# %%
# new best model has values (p,d,q) = (0,1,0)
arima = ARIMA(usdcny_post2015,order=(0,1,0))
model_fit = arima.fit()

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 2248
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                5851.655
# Date:                Thu, 21 Mar 2024   AIC                         -11693.310
# Time:                        22:02:45   BIC                         -11664.723
# Sample:                    08-03-2015   HQIC                        -11682.875
#                          - 03-14-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3552      0.281      4.825      0.000       0.805       1.906
# ar.L2         -0.4836      0.266     -1.821      0.069      -1.004       0.037
# ma.L1         -1.3734      0.276     -4.977      0.000      -1.914      -0.833
# ma.L2          0.5189      0.257      2.016      0.044       0.014       1.023
# sigma2         0.0003   5.16e-06     62.049      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):              2464.15
# Prob(Q):                              0.66   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.98   Skew:                            -0.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
residuals = model_fit.resid[1:]
fig, ax = plt.subplots(1,2)
residuals.plot(title='Residuals', ax=ax[0])
residuals.plot(title='Density',kind='kde', ax=ax[1])
plt.show()

# %%
model_df = pd.DataFrame(model_fit.predict())

# %%
model_df.head()
# Out:
#             predicted_mean
# Date
# 2015-08-03        0.000000
# 2015-08-04        6.208700
# 2015-08-05        6.208503
# 2015-08-06        6.209482
# 2015-08-07        6.209508

# %%
model_df.index =pd.to_datetime(model_df.index.to_timestamp())
print(model_df.index)
# Out:
# DatetimeIndex(['2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06', '2015-08-07', '2015-08-10', '2015-08-11', '2015-08-12', '2015-08-13', '2015-08-14',
#                ...
#                '2024-03-01', '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14'], dtype='datetime64[ns]', name='Date', length=2248, freq=None)

# %%
usdcny_post2015.index = pd.to_datetime(usdcny_post2015.index.to_timestamp())
print(usdcny_post2015.index)
# Out:
# DatetimeIndex(['2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06', '2015-08-07', '2015-08-10', '2015-08-11', '2015-08-12', '2015-08-13', '2015-08-14',
#                ...
#                '2024-03-01', '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14'], dtype='datetime64[ns]', name='Date', length=2248, freq=None)

# %%
usdcny_post2015.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
model_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
desired_start_date= '2015-12-01'
df_subset_model = model_df[model_df.index >= desired_start_date]
df_subset_actual = usdcny_post2015[usdcny_post2015.index >= desired_start_date]


plt.figure(figsize=(16,4))
plt.plot(df_subset_actual, label="Actual")
plt.plot(df_subset_model, label="Predicted")
plt.title('Exchange Rates', fontsize=20)
plt.ylabel('Rate', fontsize=16)
plt.legend()


plt.legend()

# %%
# TODO:
'''
Separate training data from testing data before fitting the model
Fit the model to the training data
use .predict from the model on the testing data and analyze prediction accuracy

If good, train the model on the entire dataset
Forecast for a year and 
'''
